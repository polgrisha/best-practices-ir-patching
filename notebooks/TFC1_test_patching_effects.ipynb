# %%
import numpy as np
import seaborn as sns
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-n5ssey4g because the default path (/scratch_local/eickhoff/esx208/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Fontconfig error: Cannot load default config file: No such file: (null)
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories
# Fontconfig error: No writable cache directories

# %%
patched_head_tfc_top_1000 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_1000_patch_head.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_1000,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >

# %%
patched_head_tfc_top_4000 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_4000_patch_head_all.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_4000,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >

# %%
patched_head_tfc_top_4000_rel_3 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_4000_patch_head_rel_3.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_4000_rel_3 ,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >

# %%
patched_head_tfc_top_4000_rel_2 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_4000_patch_head_rel_3.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_4000_rel_2,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >

# %%
patched_head_tfc_top_4000_rel_1 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_4000_patch_head_rel_1.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_4000_rel_1,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >

# %%
patched_head_tfc_top_4000_rel_0 = np.load('/mnt/qb/work/eickhoff/esx208/MechIR/data/patching/sebastian-hofstaetter-distilbert-dot-tas_b-b256-msmarco_bi_TFC1_4000_patch_head_rel_0.npy')

# %%
sns.heatmap(
        patched_head_tfc_top_4000_rel_0,
        vmin=-1,
        vmax=1,
        cmap='RdBu',)
# Out:
# <Axes: >
